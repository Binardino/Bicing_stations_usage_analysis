# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# %%
df = pd.read_csv('../Datasets/january_2020_dt.zip', compression='zip')

# %%
df
# Out:
#          station_id  bikes_avail  mechanical_avail  ebike_avail  docks_avail  \
# 0                 1           21                21            0           23
# 1                 2           10                 9            1           16
# 2                 3           15                15            0            9
# 3                 4            8                 8            0           13
# 4                 5           14                11            3           24
# ...             ...          ...               ...          ...          ...
# 3398703         474            7                 5            2            8
# 3398704         492            2                 2            0           22
# 3398705         494            0                 0            0           24
# 3398706         495            3                 2            1           19
# 3398707         496           15                13            2            0
#
# ...

# %%
df['last_updated'] = pd.to_datetime(df['last_updated'],  unit = 's')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3398708 entries, 0 to 3398707
# Data columns (total 12 columns):
# station_id          int64
# bikes_avail         int64
# mechanical_avail    int64
# ebike_avail         int64
# docks_avail         int64
# status              object
# total_slots         int64
# last_reported       object
# last_updated        datetime64[ns]
# date                object
# time                object
# weekday             int64
# dtypes: datetime64[ns](1), int64(7), object(4)
# memory usage: 311.2+ MB

# %% [markdown]
# ### Testing out station analysis on Passeig de l'Exposició station

# %%
df_234 = df[df['station_id'] == 234]

# %%
df_234
# Out:
#          station_id  bikes_avail  mechanical_avail  ebike_avail  docks_avail  \
# 223             234            1                 1            0           26
# 633             234            1                 1            0           26
# 1043            234            1                 1            0           26
# 1453            234            1                 1            0           26
# 1863            234            1                 1            0           26
# ...             ...          ...               ...          ...          ...
# 3396866         234           15                 9            6           10
# 3397279         234           15                 9            6           10
# 3397692         234           15                 9            6           10
# 3398105         234           15                 9            6           10
# 3398518         234           13                 7            6           12
#
# ...

# %%
df_234['last_updated']
# Out:
# 223       2019-12-31 23:00:23
# 633       2019-12-31 23:05:06
# 1043      2019-12-31 23:10:26
# 1453      2019-12-31 23:15:17
# 1863      2019-12-31 23:20:02
#                   ...
# 3396866   2020-01-31 22:34:54
# 3397279   2020-01-31 22:40:00
# 3397692   2020-01-31 22:45:13
# 3398105   2020-01-31 22:49:57
# 3398518   2020-01-31 22:55:01
# Name: last_updated, Length: 8257, dtype: datetime64[ns]

# %%
#resampling stations to get an average of bike usage for every hour
df_234_sample = df_234.resample('H', on='last_updated').mean()

df_234_sample
# Out:
#                      station_id  bikes_avail  mechanical_avail  ebike_avail  \
# last_updated
# 2019-12-31 23:00:00       234.0     1.000000          1.000000     0.000000
# 2020-01-01 00:00:00       234.0     0.333333          0.250000     0.083333
# 2020-01-01 01:00:00       234.0     1.000000          0.000000     1.000000
# 2020-01-01 02:00:00       234.0     0.545455          0.000000     0.545455
# 2020-01-01 03:00:00       234.0     0.000000          0.000000     0.000000
# ...                         ...          ...               ...          ...
# 2020-01-31 18:00:00       234.0    17.307692         14.153846     3.153846
# 2020-01-31 19:00:00       234.0    20.272727         14.909091     5.363636
# 2020-01-31 20:00:00       234.0    24.615385         14.153846    10.461538
# 2020-01-31 21:00:00       234.0    22.083333         11.333333    10.750000
# 2020-01-31 22:00:00       234.0    16.545455          9.454545     7.090909
#
# ...
