# %%
# import rarfile, csv
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# %%
#ignore warnings when creating datetime columns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# ### Defining functions

# %%
def station_timeline(station_id, selected_day):
    """
    Input : ID of a Bicing Station + a given day on a string format %Y-%m-%d
    Output : sub df with all Bicing logs from taht staion on that given day & plot of the day logs
    """
    
    sub_df_selected_day = df[df['last_reported_dt'].dt.strftime('%Y-%m-%d') == selected_day]
#   old  version : 
# testing lambda function sub_df_selected_day['daytime'] = sub_df_selected_day["last_reported_dt"].apply(lambda date : datetime.strptime(date, "%H-%M-%s"))

    sub_df_selected_day['daytime'] = sub_df_selected_day["last_reported_dt"].dt.time
    
    station = sub_df_selected_day.query(f'station_id == {station_id}')
    station.plot(x='daytime' , y='num_bikes_available' , style='-', figsize=(15,12))
    
    return station

# %% [markdown]
# ### Data cleaning - ETL

# %% [markdown]
# Launching data & checking raw data

# %%
df = pd.read_csv('2020_01_Gener_BicingNou_ESTACIONS.zip', compression='zip', header=0, sep=',', quotechar='"')

# %%
df
# Out:
#          station_id  num_bikes_available  \
# 0                 1                   21
# 1                 2                   10
# 2                 3                   15
# 3                 4                    8
# 4                 5                   14
# ...             ...                  ...
# 3398703         474                    7
# 3398704         492                    2
# 3398705         494                    0
# 3398706         495                    3
# 3398707         496                   15
#
#          num_bikes_available_types.mechanical  \
# 0                                          21
# 1                                           9
# 2                                          15
# 3                                           8
# 4                                          11
# ...                                       ...
# 3398703                                     5
# 3398704                                     2
# ...

# %% [markdown]
# ##### Presenting the dataframe :
# All Bicing monthly stations log are datasets with the following features :
# - **station_id** : cf. complete list of stations' id [opendata-ajuntament.barcelona.cat](https://opendata-ajuntament.barcelona.cat/data/en/dataset/bicing/resource/f59e276c-1a1e-4fa5-8c89-8a8a56e56b34)
# - **num_bikes_available** : sum of available bikes at the given timestamp
# - **num_bikes_available_types.mechanical**: sum of available Mechanical bikes
# - **num_bikes_available_types.ebike** : sum of available e-bikes
# - **num_docks_available** : sum of available docks
# - **is_installed** : **BOOL** The station is functioning correctly
# - **is_renting** : **BOOL** The station is providing bicycles properly
# - **is_returning** : **BOOL** The station is returning bicycles properly
# - **last_reported** : timestamp of last updated from the archive
# - **is_charging_station** : may charge e-bikes
# - **status** : **Obj** station status =  'IN_SERVICE', 'PLANNED', 'NOT_IN_SERVICE', 'MAINTENANCE', 'END_OF_LIFE'
# - **last_updated** : timestamp of last updated of the station
# - **ttl** : abriavation for "TimeToLive". Concretely, designs the amount of total docks for each station

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3398708 entries, 0 to 3398707
# Data columns (total 13 columns):
# station_id                              int64
# num_bikes_available                     int64
# num_bikes_available_types.mechanical    int64
# num_bikes_available_types.ebike         int64
# num_docks_available                     int64
# is_installed                            int64
# is_renting                              int64
# is_returning                            int64
# last_reported                           float64
# is_charging_station                     bool
# status                                  object
# last_updated                            int64
# ttl                                     int64
# dtypes: bool(1), float64(1), int64(10), object(1)
# memory usage: 314.4+ MB

# %% [markdown]
# Checking correlation between features with sns heatmap

# %%
#creating sub df correaltion matrix
df_corr = df.corr()

plt.figure(figsize=(20,10))

#creating mask to only display half of the correlation matrix
mask = np.triu(np.ones_like(df_corr, dtype=bool))

#corr matrix with percentage as annotation
sns.heatmap(df_corr, mask=mask, annot=True)

# %% [markdown]
# 3 features (is_installed, is_renting & is_returning) closely correlated
#
# Do not convey much useful information - may be deleting 2 or 3 out of 3 features
#
# "Status" feature encompasses all info = "In Service" or "Not"

# %%
df['status'].value_counts()
# Out:
# IN_SERVICE        3342646
# PLANNED             43921
# NOT_IN_SERVICE      12131
# END_OF_LIFE             8
# MAINTENANCE             2
# Name: status, dtype: int64

# %%
print(df['is_returning'].value_counts())

print(df['is_installed'].value_counts())
# Out:
# 1    3342646
# 0      56062
# Name: is_returning, dtype: int64
# 1    3354787
# 0      43921
# Name: is_installed, dtype: int64

# %% [markdown]
# **Creating new columns**
#
# last_reported_dt & last_updated_dt, with converted timestamps from Universal Timestamp into datetime

# %%
df['last_reported_dt'] = pd.to_datetime(df['last_reported'],  unit = 's')

df['last_updated_dt'] = pd.to_datetime(df['last_updated'], unit = 's')

# %%
df['last_reported_dt'].unique()
# Out:
# array(['2019-12-31T22:56:44.000000000', '2019-12-31T22:57:58.000000000',
#        '2019-12-31T22:56:20.000000000', ...,
#        '2020-01-31T22:54:17.000000000', '2020-01-31T22:54:46.000000000',
#        '2020-01-31T22:54:35.000000000'], dtype='datetime64[ns]')

# %%
df
# Out:
#          station_id  num_bikes_available  \
# 0                 1                   21
# 1                 2                   10
# 2                 3                   15
# 3                 4                    8
# 4                 5                   14
# ...             ...                  ...
# 3398703         474                    7
# 3398704         492                    2
# 3398705         494                    0
# 3398706         495                    3
# 3398707         496                   15
#
#          num_bikes_available_types.mechanical  \
# 0                                          21
# 1                                           9
# 2                                          15
# 3                                           8
# 4                                          11
# ...                                       ...
# 3398703                                     5
# 3398704                                     2
# ...

# %%
# pg_exposicio = df.query('station_id== 234')

# %%
# pg_exposicio['hour'] = pg_exposicio["last_reported_dt"].apply(lambda date : datetime.strptime(date, "%H-%M-%s"))

# %%
# df['last_reported_dt'].dt.date

# %%
station_timeline(234, "2020-01-02")
# Out:
# <ipython-input-47-a77b05230a6e>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df_selected_day['daytime'] = sub_df_selected_day["last_reported_dt"].dt.time
#         station_id  num_bikes_available  num_bikes_available_types.mechanical  \
# 123633         234                    0                                     0
# 124043         234                    0                                     0
# 124453         234                    0                                     0
# 124863         234                    0                                     0
# 125273         234                    0                                     0
# ...            ...                  ...                                   ...
# ...

# %%
#We will check Ironhack's closest station and see how does it behave on a regular day.
ironhack = df[df['station_id'] == 211]

# %%
df
# Out:
#          station_id  num_bikes_available  \
# 0                 1                   21
# 1                 2                   10
# 2                 3                   15
# 3                 4                    8
# 4                 5                   14
# ...             ...                  ...
# 3398703         474                    7
# 3398704         492                    2
# 3398705         494                    0
# 3398706         495                    3
# 3398707         496                   15
#
#          num_bikes_available_types.mechanical  \
# 0                                          21
# 1                                           9
# 2                                          15
# 3                                           8
# 4                                          11
# ...                                       ...
# 3398703                                     5
# 3398704                                     2
# ...

# %% [markdown]
# ### Creating new datetime features

# %%
df['date'] = [date.date() for date in df['last_updated_dt']]

df['time'] = [time.time() for time in df['last_updated_dt']]

# %%
df
# Out:
#          station_id  num_bikes_available  \
# 0                 1                   21
# 1                 2                   10
# 2                 3                   15
# 3                 4                    8
# 4                 5                   14
# ...             ...                  ...
# 3398703         474                    7
# 3398704         492                    2
# 3398705         494                    0
# 3398706         495                    3
# 3398707         496                   15
#
#          num_bikes_available_types.mechanical  \
# 0                                          21
# 1                                           9
# 2                                          15
# 3                                           8
# 4                                          11
# ...                                       ...
# 3398703                                     5
# 3398704                                     2
# ...

# %%
df['weekday'] = [day.weekday() for day in df['last_updated_dt']]

# %%
df
# Out:
#          station_id  num_bikes_available  \
# 0                 1                   21
# 1                 2                   10
# 2                 3                   15
# 3                 4                    8
# 4                 5                   14
# ...             ...                  ...
# 3398703         474                    7
# 3398704         492                    2
# 3398705         494                    0
# 3398706         495                    3
# 3398707         496                   15
#
#          num_bikes_available_types.mechanical  \
# 0                                          21
# 1                                           9
# 2                                          15
# 3                                           8
# 4                                          11
# ...                                       ...
# 3398703                                     5
# 3398704                                     2
# ...
